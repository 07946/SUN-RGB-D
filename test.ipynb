# %%
from sun import SUN

# %%
sunrgbd = SUN()
# Out:
# loading metadata into memory...
# Done (t=2.75s)

# %%
kv1Index=sunrgbd.getSensorDataId('kv1')

# %%
sunrgbd.visImg(kv1Index[0])

# %%
sunrgbd.visPointCloud(kv1Index[0])

# %%
from bbox import Bbox3d

# %%
cl=sunrgbd.getCornerList(kv1Index[0])

# %%
sunrgbd.visCube(kv1Index[0],1)
